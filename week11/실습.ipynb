# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Input

# %% [markdown]
# 데이터 로드 및 확인

# %%
# 데이터 로드
df = pd.read_csv('seeds_dataset.txt', sep='\s+', header=None)

# 데이터 확인
df
# Out:
#          0      1       2      3      4      5      6  7
# 0    15.26  14.84  0.8710  5.763  3.312  2.221  5.220  1
# 1    14.88  14.57  0.8811  5.554  3.333  1.018  4.956  1
# 2    14.29  14.09  0.9050  5.291  3.337  2.699  4.825  1
# 3    13.84  13.94  0.8955  5.324  3.379  2.259  4.805  1
# 4    16.14  14.99  0.9034  5.658  3.562  1.355  5.175  1
# ..     ...    ...     ...    ...    ...    ...    ... ..
# 205  12.19  13.20  0.8783  5.137  2.981  3.631  4.870  3
# 206  11.23  12.88  0.8511  5.140  2.795  4.325  5.003  3
# 207  13.20  13.66  0.8883  5.236  3.232  8.315  5.056  3
# 208  11.84  13.21  0.8521  5.175  2.836  3.598  5.044  3
# 209  12.30  13.34  0.8684  5.243  2.974  5.637  5.063  3
#
# [210 rows x 8 columns]

# %% [markdown]
# 레이블 및 전처리

# %%
# 특성과 타겟 분리
X = df.drop(columns=[7])  # 0~6번 열: 특성
y = df[7]  # 7번 열: 클래스 (1, 2, 3)

# 클래스 라벨을 0부터 시작하도록 조정 (1 → 0, 2 → 1, 3 → 2)
y = y - 1

# 원-핫 인코딩
y_one_hot = to_categorical(y, num_classes=3)

# %% [markdown]
# 훈련 데이터

# %%
# 3. 훈련/테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.2, random_state=42)

# %% [markdown]
# 데이터 스케일링

# %%
# 4. 데이터 스케일링
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Sequential API 방법

# %%
model_seq = Sequential()
model_seq.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model_seq.add(Dense(32, activation='relu'))
model_seq.add(Dense(3, activation='softmax'))

model_seq.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(patience=5, restore_best_weights=True)

model_seq.fit(X_train, y_train, epochs=50, batch_size=16,
              validation_split=0.2, callbacks=[early_stop])

# 평가
loss, acc = model_seq.evaluate(X_test, y_test)
print(f"Sequential 모델 정확도: {acc:.4f}")
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.2002 - loss: 1.1530 - val_accuracy: 0.5882 - val_loss: 0.8924
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6674 - loss: 0.8976 - val_accuracy: 0.9118 - val_loss: 0.6811
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8919 - loss: 0.7175 - val_accuracy: 0.9118 - val_loss: 0.5464
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8822 - loss: 0.5890 - val_accuracy: 0.9412 - val_loss: 0.4484
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9264 - loss: 0.5111 - val_accuracy: 0.9412 - val_loss: 0.3757
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9409 - loss: 0.4286 - val_accuracy: 0.9412 - val_loss: 0.3186
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9251 - loss: 0.3851 - val_accuracy: 0.9118 - val_loss: 0.2754
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9249 - loss: 0.3157 - val_accuracy: 0.9118 - val_loss: 0.2410
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9244 - loss: 0.2748 - val_accuracy: 0.9118 - val_loss: 0.2190
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9408 - loss: 0.2314 - val_accuracy: 0.9118 - val_loss: 0.2001
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9397 - loss: 0.2243 - val_accuracy: 0.9118 - val_loss: 0.1869
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9415 - loss: 0.1932 - val_accuracy: 0.9118 - val_loss: 0.1704
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9015 - loss: 0.2019 - val_accuracy: 0.9118 - val_loss: 0.1625
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9603 - loss: 0.1785 - val_accuracy: 0.9118 - val_loss: 0.1624
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9369 - loss: 0.1861 - val_accuracy: 0.9118 - val_loss: 0.1638
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9514 - loss: 0.1520 - val_accuracy: 0.9118 - val_loss: 0.1550
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9511 - loss: 0.1617 - val_accuracy: 0.9118 - val_loss: 0.1460
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9641 - loss: 0.1382 - val_accuracy: 0.9118 - val_loss: 0.1427
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9646 - loss: 0.1392 - val_accuracy: 0.9118 - val_loss: 0.1437
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9367 - loss: 0.1533 - val_accuracy: 0.9118 - val_loss: 0.1396
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9323 - loss: 0.1528 - val_accuracy: 0.9412 - val_loss: 0.1376
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9451 - loss: 0.1536 - val_accuracy: 0.9412 - val_loss: 0.1346
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9676 - loss: 0.1140 - val_accuracy: 0.9412 - val_loss: 0.1368
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9444 - loss: 0.1281 - val_accuracy: 0.9412 - val_loss: 0.1315
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9617 - loss: 0.1252 - val_accuracy: 0.9412 - val_loss: 0.1272
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9735 - loss: 0.1016 - val_accuracy: 0.9412 - val_loss: 0.1253
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9676 - loss: 0.1234 - val_accuracy: 0.9412 - val_loss: 0.1223
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9531 - loss: 0.1367 - val_accuracy: 0.9412 - val_loss: 0.1297
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9662 - loss: 0.1018 - val_accuracy: 0.9412 - val_loss: 0.1336
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9565 - loss: 0.1326 - val_accuracy: 0.9412 - val_loss: 0.1440
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9579 - loss: 0.1067 - val_accuracy: 0.9412 - val_loss: 0.1335
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9561 - loss: 0.1039 - val_accuracy: 0.9412 - val_loss: 0.1299
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9211 - loss: 0.1816
# Sequential 모델 정확도: 0.9286

# %% [markdown]
# Functional API 버전

# %%
inputs = Input(shape=(X_train.shape[1],))
x = Dense(64, activation='relu')(inputs)
x = Dense(32, activation='relu')(x)
outputs = Dense(3, activation='softmax')(x)

model_func = Model(inputs=inputs, outputs=outputs)
model_func.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(patience=5, restore_best_weights=True)

model_func.fit(X_train, y_train, epochs=50, batch_size=16,
               validation_split=0.2, callbacks=[early_stop])

# 평가
loss, acc = model_func.evaluate(X_test, y_test)
print(f"Functional API 모델 정확도: {acc:.4f}")
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.2824 - loss: 1.1119 - val_accuracy: 0.8529 - val_loss: 0.8328
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8871 - loss: 0.7956 - val_accuracy: 0.9118 - val_loss: 0.5747
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8808 - loss: 0.6187 - val_accuracy: 0.9118 - val_loss: 0.4365
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8803 - loss: 0.4887 - val_accuracy: 0.9118 - val_loss: 0.3537
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8766 - loss: 0.3946 - val_accuracy: 0.9412 - val_loss: 0.3019
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8706 - loss: 0.3787 - val_accuracy: 0.9412 - val_loss: 0.2615
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9046 - loss: 0.3319 - val_accuracy: 0.9412 - val_loss: 0.2333
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8922 - loss: 0.3055 - val_accuracy: 0.9412 - val_loss: 0.2110
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9130 - loss: 0.2671 - val_accuracy: 0.9412 - val_loss: 0.1944
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9376 - loss: 0.2337 - val_accuracy: 0.9412 - val_loss: 0.1788
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8893 - loss: 0.2527 - val_accuracy: 0.9412 - val_loss: 0.1648
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9041 - loss: 0.2571 - val_accuracy: 0.9118 - val_loss: 0.1590
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9448 - loss: 0.1825 - val_accuracy: 0.9118 - val_loss: 0.1528
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9109 - loss: 0.2120 - val_accuracy: 0.9118 - val_loss: 0.1500
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9214 - loss: 0.2070 - val_accuracy: 0.9118 - val_loss: 0.1456
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8950 - loss: 0.1991 - val_accuracy: 0.9118 - val_loss: 0.1423
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9278 - loss: 0.1645 - val_accuracy: 0.9118 - val_loss: 0.1310
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8896 - loss: 0.2284 - val_accuracy: 0.9118 - val_loss: 0.1239
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8969 - loss: 0.2046 - val_accuracy: 0.9118 - val_loss: 0.1246
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9174 - loss: 0.1694 - val_accuracy: 0.9118 - val_loss: 0.1254
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9003 - loss: 0.1920 - val_accuracy: 0.9118 - val_loss: 0.1240
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9290 - loss: 0.1548 - val_accuracy: 0.9412 - val_loss: 0.1192
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9129 - loss: 0.1955 - val_accuracy: 0.9412 - val_loss: 0.1188
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9473 - loss: 0.1760 - val_accuracy: 0.9412 - val_loss: 0.1118
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9522 - loss: 0.1313 - val_accuracy: 0.9412 - val_loss: 0.1193
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9516 - loss: 0.1240 - val_accuracy: 0.9412 - val_loss: 0.1213
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9515 - loss: 0.1297 - val_accuracy: 0.9412 - val_loss: 0.1135
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9740 - loss: 0.0901 - val_accuracy: 0.9412 - val_loss: 0.1075
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9438 - loss: 0.1543 - val_accuracy: 0.9412 - val_loss: 0.1125
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9568 - loss: 0.1107 - val_accuracy: 0.9412 - val_loss: 0.1225
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9583 - loss: 0.1126 - val_accuracy: 0.9412 - val_loss: 0.1105
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9320 - loss: 0.1581 - val_accuracy: 0.9412 - val_loss: 0.0990
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9383 - loss: 0.1285 - val_accuracy: 0.9412 - val_loss: 0.1023
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9712 - loss: 0.0891 - val_accuracy: 0.9412 - val_loss: 0.1066
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9630 - loss: 0.0929 - val_accuracy: 0.9412 - val_loss: 0.1047
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9564 - loss: 0.1144 - val_accuracy: 0.9412 - val_loss: 0.1040
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9679 - loss: 0.0795 - val_accuracy: 0.9412 - val_loss: 0.1067
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9211 - loss: 0.1652
# Functional API 모델 정확도: 0.9286

# %% [markdown]
# Subclassing API 버전

# %%
class MyModel(Model):
    def __init__(self):
        super(MyModel, self).__init__()
        self.dense1 = Dense(64, activation='relu')
        self.dense2 = Dense(32, activation='relu')
        self.out = Dense(3, activation='softmax')

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.out(x)

model_sub = MyModel()
model_sub.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(patience=5, restore_best_weights=True)

model_sub.fit(X_train, y_train, epochs=50, batch_size=16,
              validation_split=0.2, callbacks=[early_stop])

# 평가
loss, acc = model_sub.evaluate(X_test, y_test)
print(f"Subclassing 모델 정확도: {acc:.4f}")
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.2982 - loss: 1.1107 - val_accuracy: 0.6471 - val_loss: 0.8773
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.